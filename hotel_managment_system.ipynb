# %%
#canteen services
def welcome():
    print("---------------welcome---------------")
    print("select the options for your meal ")
    print("1 for SNACKS")
    print("2 for CHINESE")
    print("3 for BEVERAGES")
    print()
    menu()
def new_item():
        print("1 for SNACKS")
        print("2 for CHINESE")
        print("3 for BEVERAGES")
        menu()
def menu():
    option = int(input("enter your option  1/2/3 or 0 for exit"))
    if(option ==1):
        print("------------SNACKS------------")
        snacks()
        new_item()
    elif(option ==2):
        print("------------CHINESE------------")
        chinese()
        new_item()
        
    elif(option ==3):
        print("------------BEVERAGES------------")
        beverages()
        new_item()
        
    elif(option==0):
        print("exit")
        exit = input("do you want to exit (yes/no) :")
        if(exit=="yes"):
            print("________________THANK YOU__________________")
            final_price()
        else:
            new_item()
    else:
        print("invalid input")
        option = int(input("enter your option again : "))
#         add(option)
# def add(option):
#      menu(option)
        
quantity =0
def snacks():
    global quantity
    print("1 for SAMOSA -->20 rs")
    print("2 for DOSA   -->40 rs")
    print("3 for IDLI   -->2o rs")
    print("4 for POHA   -->20 rs")
    dish_name = int(input("enter your dish name: "))
    quantity = int(input("enter your quantity of dish : ")) 
#     quantity = qunatity
    bill(dish_name,quantity)
    
#     snacks_options = int(input("enter your options : "))
    
def chinese():
    print("1 for FRIED RICE -->30 rs")
    print("2 for MANCHURIAN -->40 rs")
    print("3 for NOODLES    -->40 rs")
    print("4  for MOMOS     -->80 rs")
    dish_name =int(input("enter your dish name: "))
    quantity = int(input("enter your quantity of dish : "))
    bill(dish_name,quantity)
    
#     chinese_options = int(input("enter your options : "))    
    
def beverages():
    print("1 for coca cola -->50 rs")
    print("2 for sprit     -->20 rs")
    print("3 for smoothy   -->10 rs")
    print("4 for slice     -->40 rs")
    dish_name = int(input("enter your dish name: "))
   
        
    quantity = int(input("enter your quantity of dish : ")) 
    bill(dish_name,quantity)
   
#     beverages_options = int(input("enter your options : ")) 
total=0
def bill(dish_name,quantity):
    global total
  
        
    if(dish_name==1):
        bill = quantity * 25
        total = bill +total 
        print("bill for Samosa for quantity ",quantity ,"is : ",bill,"Rs") 
        print("total is :  ",total,"Rs")
        
    elif(dish_name == 2):
        bill = quantity * 40
        total = bill +total
        
        print("bill for Dosa for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 3):
        bill = quantity * 20
        total = bill +total
        
        print("bill for Dosa for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 4):
        bill = quantity * 20
        total = bill +total
        
        print("bill for POHA for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name ==1):
        bill = quantity * 30
        total = bill +total
        
        print("bill for FRIED RICE for quantity ",quantity ,"is : ",bill,"Rs")
    elif(dish_name ==2):
        bill = quantity * 40
        total = bill +total
        
        print("bill for MANCHURIAN for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 3):
        bill = quantity * 40
        total = bill +total
        
        print("bill for NOODLES for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 4):
        bill = quantity * 80
        total = bill +total
        
        print("bill for MOMOS for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 1):
        bill = quantity * 50
        total = bill +total

        print("bill for coca cola for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 2):
        bill = quantity * 30
        total = bill +total

        
        print("bill for sprit for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 3):
        bill = quantity * 10
        total = bill +total
        
        print("bill for smoothy for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 
        
    elif(dish_name == 4):
        bill = quantity * 40
        total = bill +total
        
        print("bill for slice for quantity ",quantity ,"is : ",bill,"Rs")
        print("total is :  ",total,"Rs") 

def final_price():
    print("your total cost is :",total)
    day = input("enter today's day(please enter in small case) : ")
    if(day=="monday"):
        print("today's discount offer is : 5%")
        discount = total*5/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="tuesday"):
        print("today's discount offer is : 7%")
        discount = total*7/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="wednesday"):
        print("today's discount offer is : 3%")
        discount = total*3/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="thusday"):
        print("today's discount offer is : 8%")
        discount = total*8/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="friday"):
        print("today's discount offer is : 9%")
        discount = total*9/100;
        finaltotal =total -discount      
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="saturday"):
        print("today's discount offer is : 10%")
        discount = total*10/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal)
        gst(finaltotal)
    elif(day=="sunday"):
        print("today's discount offer is : 15%")
        discount = total*15/100;
        finaltotal =total -discount
        print("your discount is : ",discount)
        print("your total bill is : ",finaltotal) 
        gst(finaltotal)
     

welcome()
# Out:
# ---------------welcome---------------
# select the options for your meal
# 1 for SNACKS
# 2 for CHINESE
# 3 for BEVERAGES
#
# enter your option  1/2/3 or 0 for exit1
# ------------SNACKS------------
# 1 for SAMOSA -->20 rs
# 2 for DOSA   -->40 rs
# 3 for IDLI   -->2o rs
# 4 for POHA   -->20 rs
# enter your dish name: 1
# enter your quantity of dish : 1
# bill for Samosa for quantity  1 is :  25 Rs
# total is :   25 Rs
# 1 for SNACKS
# 2 for CHINESE
# 3 for BEVERAGES
# enter your option  1/2/3 or 0 for exit1
# ------------SNACKS------------
# 1 for SAMOSA -->20 rs
# 2 for DOSA   -->40 rs
# 3 for IDLI   -->2o rs
# 4 for POHA   -->20 rs
# enter your dish name: 1
# enter your quantity of dish : 1
# bill for Samosa for quantity  1 is :  25 Rs
# total is :   50 Rs
# 1 for SNACKS
# 2 for CHINESE
# 3 for BEVERAGES
# enter your option  1/2/3 or 0 for exit0
# exit
# do you want to exit (yes/no) :yes
# ________________THANK YOU__________________
# your total cost is : 50
# ...

# %% [markdown]
# #
